# %%
# %cd "/content/drive/MyDrive/cs224n/a3"
# Out:
# /content/drive/.shortcut-targets-by-id/10xFqb7FKPlSctOF3r8wX-SQzZLJ06WjT/cs224n/a3

# %%
# !cat run_cuda.py
# Out:
# #!/usr/bin/env python3
# # -*- coding: utf-8 -*-
# """
# CS224N 2020-2021: Homework 3
# run.py: Run the dependency parser.
# Sahil Chopra <schopra8@stanford.edu>
# Haoshen Hong <haoshen@stanford.edu>
# """
# from datetime import datetime
# import os
# import pickle
# import math
# import time
# import argparse
#
# from torch import nn, optim
# import torch
# from tqdm import tqdm
#
# from parser_model_cuda import ParserModel
# from utils.parser_utils_cuda import minibatches, load_and_preprocess_data, AverageMeter
# from torch.profiler import profile, record_function, ProfilerActivity
# import torch.cuda
# import numpy as np
#
# parser = argparse.ArgumentParser(description='Train neural dependency parser in pytorch')
# parser.add_argument('-d', '--debug', action='store_true', help='whether to enter debug mode')
# args = parser.parse_args()
#
# # -----------------
# # Primary Functions
# # -----------------
# ...

# %%
# !python run_cuda.py
# Out:
# ...
# INITIALIZING
# ...
# Loading data...
# took 2.89 seconds
# Building parser...
# took 1.25 seconds
# Loading pretrained embeddings...
# took 3.05 seconds
# Vectorizing data...
# took 1.83 seconds
# Preprocessing training data...
# took 39.48 seconds
# took 0.00 seconds
#
# ...
# TRAINING
# ...
# results/20220910_165200/
# 400 5
# /usr/local/lib/python3.7/dist-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='mean' instead.
#   warnings.warn(warning.format(ret))
# Epoch 1 out of 10
# 100% 1848/1848 [00:38<00:00, 48.55it/s]
# Average Train Loss: 0.15252256788135993
# Evaluating on dev set
# 1445850it [00:00, 46854887.96it/s]
# - dev UAS: 84.73
# New best dev UAS! Saving model.
#
# Epoch 2 out of 10
# 100% 1848/1848 [00:36<00:00, 50.06it/s]
# Average Train Loss: 0.09188262416348184
# Evaluating on dev set
# 1445850it [00:00, 47688332.09it/s]
# - dev UAS: 86.75
# New best dev UAS! Saving model.
#
# Epoch 3 out of 10
# ...

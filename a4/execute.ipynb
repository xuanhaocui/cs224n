# %%
# %cd drive/MyDrive/cs224n/a4
# Out:
# /content/drive/.shortcut-targets-by-id/10xFqb7FKPlSctOF3r8wX-SQzZLJ06WjT/cs224n/a4

# %%
# !pip install -r gpu_requirements.txt
# !pip install tqdm==4.48.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 46 kB 3.8 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 15.4 MB/s
# ...
#      |████████████████████████████████| 116 kB 67.3 MB/s
# ...
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13723 sha256=a8ecd93ce5fe08d588967761b07f0733c39329667d822dab61cf2c9f9b5c32d4
#   Stored in directory: /root/.cache/pip/wheels/72/b0/3f/1d95f96ff986c7dfffe46ce2be4062f38ebd04b506c77c81b9
# Successfully built docopt
# ...
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.64.1
#     Uninstalling tqdm-4.64.1:
#       Successfully uninstalled tqdm-4.64.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spacy 3.4.1 requires tqdm<5.0.0,>=4.38.0, but you have tqdm 4.29.1 which is incompatible.
# ...

# %%
# !sh run.sh train
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# uniformly initialize parameters [-0.100000, +0.100000]
# use device: cuda:0
# begin Maximum Likelihood training
# epoch 1, iter 10, avg. loss 199.69, avg. ppl 3274.81 cum. examples 320, speed 2174.37 words/sec, time elapsed 3.63 sec
# epoch 1, iter 20, avg. loss 165.35, avg. ppl 783.57 cum. examples 640, speed 3386.00 words/sec, time elapsed 5.98 sec
# epoch 1, iter 30, avg. loss 147.33, avg. ppl 542.03 cum. examples 960, speed 3210.00 words/sec, time elapsed 8.31 sec
# epoch 1, iter 40, avg. loss 146.49, avg. ppl 429.96 cum. examples 1280, speed 3378.51 words/sec, time elapsed 10.60 sec
# epoch 1, iter 50, avg. loss 148.21, avg. ppl 396.95 cum. examples 1600, speed 3512.99 words/sec, time elapsed 12.85 sec
# epoch 1, iter 60, avg. loss 154.45, avg. ppl 378.25 cum. examples 1920, speed 3399.44 words/sec, time elapsed 15.30 sec
# ...
